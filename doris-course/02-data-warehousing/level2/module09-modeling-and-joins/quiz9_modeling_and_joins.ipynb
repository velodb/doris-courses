# %% [markdown]
# <div style="border-top:4px solid #0f766e;padding:32px 0 20px">
# <div style="color:#0f766e;font-size:13px;font-weight:700;letter-spacing:.8px">数据仓库课程 · 离线测验</div>
# <div style="color:#17212b;font-size:30px;font-weight:750">模块 9：数仓建模与 JOIN</div>
# <p style="color:#475569;font-size:15px;line-height:1.7">共 5 道单选题，提交后立即显示反馈。不需要连接数据库。</p>
# </div>
#
# [课程说明](course.md) · [动手实验](lab9_modeling_and_joins.ipynb)
#
# ### 加载测验
#
# 运行下一个单元加载题目。重启内核后请从这里重新运行。
#
# ## 开始测验
#
# 选择答案并提交，然后阅读解析再进入下一题。

# %% [markdown]
# ### 加载测验
#
# 运行下一个单元加载题目。重启内核后请从这里重新运行。

# %%
from pathlib import Path
import sys

COURSE_ROOT = next(path for path in (Path.cwd(), *Path.cwd().parents) if (path / "dw_course").is_dir())
if str(COURSE_ROOT) not in sys.path:
    sys.path.insert(0, str(COURSE_ROOT))

from dw_course.quiz import CourseQuiz
from dw_course.runtime import COURSE_ROOT

quiz = CourseQuiz.from_yaml(COURSE_ROOT / "level2/module09-modeling-and-joins/quiz9_modeling_and_joins.yaml")

# %% [markdown]
# ## 开始测验
#
# 选择答案并提交，然后阅读解析再进入下一题。

# %%
quiz.show();
