# %% [markdown]
# <div style="max-width:100%;box-sizing:border-box;overflow:visible;border-top:4px solid #0f766e;padding:32px 0 20px;margin:0 0 24px">
#   <div style="display:block;color:#0f766e;font-size:13px;line-height:1.8;font-weight:700;letter-spacing:0.8px;text-transform:uppercase;margin:0 0 8px">QUIZ 9A · DATA WAREHOUSING WITH APACHE DORIS</div>
#   <div style="color:#17212b;font-size:30px;line-height:1.3;font-weight:750;margin:0 0 10px">知识测验</div>
#   <p style="color:#475569;font-size:15px;line-height:1.7;max-width:900px;margin:0">五道单选题，逐题查看反馈；无需连接数据库。</p>
#   <span style="display:inline-block;border:1px solid #99f6e4;border-radius:4px;background:#f0fdfa;color:#115e59;padding:6px 10px;margin-top:14px;font-size:12px">5 questions · Single choice · Approximately 5 minutes</span>
# </div>
#
# [讲义](course9a_data_quality_and_schema_validation.md) · [Lab](lab9a_validate_orders.ipynb)

# %% [markdown]
# ### Initialize the Quiz
#
# 初始化共享测验组件，不连接数据库。重启内核后重新运行。

# %%
from pathlib import Path
import sys

COURSE_ROOT = next(
    path for path in (Path.cwd(), *Path.cwd().parents)
    if (path / "dw_course").is_dir()
)
if str(COURSE_ROOT) not in sys.path:
    sys.path.insert(0, str(COURSE_ROOT))

from dw_course.quiz import CourseQuiz
from dw_course.runtime import COURSE_ROOT

quiz = CourseQuiz.from_yaml(COURSE_ROOT / "level1/module09a-data-quality/quiz9a_data_quality_and_rejection.yaml")

# %% [markdown]
# ## Start the knowledge check
#
# 选择答案并提交，阅读解释后进入下一题。

# %%
quiz.show();
