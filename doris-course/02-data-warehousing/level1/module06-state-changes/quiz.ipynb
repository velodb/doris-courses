# %% [markdown]
# # D06 知识测验
#
# [讲义](course.md) · [Lab](lab6_current_state_and_replay.ipynb)
#
# 五道单选题，约五分钟。复用实时分析课程的交互组件；不连接 Doris，不改变任何数据。

# %%
from dw_course.quiz import CourseQuiz
from dw_course.runtime import COURSE_ROOT

quiz = CourseQuiz.from_yaml(COURSE_ROOT / "level1/module06-state-changes/quiz.yaml")
quiz.show()
